# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
transactions = pd.read_excel(r"/Users/Emmanuel Adigun/Documents/kpmg_new_data.xlsx",
                           sheet_name="Transactions")

#print first 5 rows
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#convert date columns/fields from integer to datetime
transactions['transaction_date'] = pd.to_datetime(transactions['transaction_date'], unit='s')
transactions['transaction_date'].head()
# Out:
# 0   2017-02-25
# 1   2017-05-21
# 2   2017-10-16
# 3   2017-08-31
# 4   2017-10-01
# Name: transaction_date, dtype: datetime64[ns]

# %%
#convert date columns/fields from integer to datetime
transactions['product_first_sold_date'] = pd.to_datetime(transactions['product_first_sold_date'], unit='s')
transactions['product_first_sold_date'].head()
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
transactions.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %% [markdown]
# Exploring Missing Values

# %%
#Identify Missing Values

# %%
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
dups = transactions[transactions.duplicated()]
dups.sum()
# Out:
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# transaction_date           0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %% [markdown]
# Exploring Columns

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %% [markdown]
# All columns appear to have consistent and correct information

# %% [markdown]
# Exploring New Customer List Dataset

# %%
new_customer_list = pd.read_excel(r"/Users/Emmanuel Adigun/Documents/kpmg_new_data.xlsx",
                           sheet_name="NewCustomerList")

#print first 5 rows
new_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
new_customer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
#Drop Unnamed columns
new_customer_list.drop(new_customer_list.columns[16:21], axis=1)
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
#Check for null values
new_customer_list.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# dtype: int64

# %%
#Checking for duplicate values
new_customer_list.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Explore Columns

# %%
new_customer_list['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
# Replace 'U' with 'Unspecified'
new_customer_list['gender'] = new_customer_list['gender'].replace(['U'],'Unspecified')
new_customer_list['gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: gender, Length: 1000, dtype: object

# %%
new_customer_list['gender'].value_counts()
# Out:
# Female         513
# Male           470
# Unspecified     17
# Name: gender, dtype: int64

# %%
new_customer_list['DOB'].describe()
# Out:
# count                     983
# unique                    958
# top       1961-07-31 00:00:00
# freq                        2
# first     1938-06-08 00:00:00
# last      2002-02-27 00:00:00
# Name: DOB, dtype: object

# %% [markdown]
# Exploring Customer Demographic

# %%
customer_demographic = pd.read_excel(r"/Users/Emmanuel Adigun/Documents/kpmg_new_data.xlsx",
                           sheet_name="CustomerDemographic")

# %%
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
customer_demographic['default'].value_counts()
# Out:
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# Ù¡Ù¢Ù£                                     53
#                                          ...
# <img src=x onerror=alert('hi') />          31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64

# %% [markdown]
# Values in the default columns are not correct, so we will drop the column

# %%
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
customer_demographic.sort_values(by='DOB') #Sorting by DOB shows the age begin at 1843
# Out:
#       customer_id first_name  last_name  gender  \
# 33             34   Jephthah   Bachmann       U
# 719           720     Darrel      Canet    Male
# 1091         1092     Katlin    Creddon  Female
# 3409         3410    Merrili    Brittin  Female
# 2412         2413      Abbey     Murrow    Male
# ...           ...        ...        ...     ...
# 3778         3779      Ulick     Daspar       U
# 3882         3883      Nissa     Conrad       U
# 3930         3931      Kylie      Epine       U
# 3934         3935     Teodor  Alfonsini       U
# 3997         3998     Sarene    Woolley       U
#
#       past_3_years_bike_related_purchases        DOB  \
# 33                                     59 1843-12-21
# 719                                    67 1931-10-23
# 1091                                   56 1935-08-22
# 3409                                   93 1940-09-22
# 2412                                   27 1943-08-11
# ...                                   ...        ...
# ...

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
customer_demographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# M            1
# Femal        1
# F            1
# Name: gender, dtype: int64

# %% [markdown]
# The gender column contains inconsistent values that needs to be replaced with their appropriate values

# %%
# Replace inconsistent values with appropriate values
customer_demographic['gender'] = customer_demographic['gender'].replace(['F'],'Female').replace(['M'],'Male').replace(['Femal'],'Female').replace(['U'],'Unspecified')
customer_demographic['gender'].value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %% [markdown]
# Merge all customers information from three tables into One table

# %%
new_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
customer_demographic.head(10)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
# 5            6            Curr  Duckhouse    Male
# 6            7            Fina     Merali  Female
# 7            8             Rod      Inder    Male
# 8            9            Mala       Lind  Female
# 9           10        Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 3                                   33 1961-10-03
# 4                                   56 1977-05-13
# 5                                   35 1966-09-16
# 6                                    6 1976-02-23
# ...

# %%
customer_demographic['customer_id'].iloc[-1]
# Out:
# 4000

# %% [markdown]
# We need to add the Customer Id column to 'new_customer_list' to enable us merge tables vertically

# %%
new_customer_list.insert(0, 'customer_id', range(4001, 4001 + len(new_customer_list)))

# %%
new_customer_list.head(5)
# Out:
#    customer_id first_name  last_name  gender  \
# 0         4001    Chickie    Brister    Male
# 1         4002      Morly     Genery    Male
# 2         4003    Ardelis  Forrester  Female
# 3         4004     Lucine      Stutt  Female
# 4         4005    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# ...

# %% [markdown]
# We need to mearge Customer Demographic with the Customer Address before joining with New Customer List

# %%
customer_address = pd.read_excel(r"/Users/Emmanuel Adigun/Documents/kpmg_new_data.xlsx",
                           sheet_name="CustomerAddress")

# %%
customer_address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
#Merge dataframes using customer_id column
customer_demographic = pd.merge(customer_demographic, customer_address, how='left', on='customer_id')

# %%
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
new_customer_list.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         4001    Chickie    Brister    Male
# 1         4002      Morly     Genery    Male
# 2         4003    Ardelis  Forrester  Female
# 3         4004     Lucine      Stutt  Female
# 4         4005    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases        DOB                   job_title  \
# 0                                   86 1957-07-12             General Manager
# 1                                   69 1970-03-22         Structural Engineer
# 2                                   10 1974-08-28      Senior Cost Accountant
# 3                                   64 1979-01-28  Account Representative III
# 4                                   34 1965-09-21           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# ...

# %%
new_df = pd.concat([customer_demographic, new_customer_list], ignore_index = True, sort = False)

# %%
new_df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 4995         4996       Ferdinand  Romanetti    Male
# 4996         4997            Burk    Wortley    Male
# 4997         4998        Melloney      Temby  Female
# 4998         4999          Dickie    Cubbini    Male
# 4999         5000           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 4                                      56 1977-05-13
# ...

# %% [markdown]
# We would assign the new dataframe to customer demographic where we will use one dataframe to capture all the customer information

# %%
customer_demographic = new_df

# %%
customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 4995         4996       Ferdinand  Romanetti    Male
# 4996         4997            Burk    Wortley    Male
# 4997         4998        Melloney      Temby  Female
# 4998         4999          Dickie    Cubbini    Male
# 4999         5000           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 4                                      56 1977-05-13
# ...
